# %%
import numpy as np
from keras.datasets import mnist
import keras
from keras import layers
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Wczytanie i konwersja danych

# %%
training_set, test_set = mnist.load_data()

# %%
X_train, y_train = training_set
X_test, y_test = test_set
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print(X_train.shape)
X_train = X_train.astype(np.float) / 255.0  
X_test = X_test.astype(np.float) / 255.0
# Out:
# (60000, 28, 28, 1)
# <ipython-input-4-bbbf7949f131>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_train = X_train.astype(np.float) / 255.0
# <ipython-input-4-bbbf7949f131>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_test = X_test.astype(np.float) / 255.0

# %% [markdown]
# Przygotowanie eksperymentu

# %%
num_classes = 10
input_shape = (28, 28, 1)
batch_size = 128
epochs = 30

# %%
model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            keras.layers.Flatten(),
            layers.Dense(num_classes, activation="softmax")
        ]
    )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 10)                7850
#
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# Uczenie modelu

# %%
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.7433 - accuracy: 0.8161 - val_loss: 0.4070 - val_accuracy: 0.8977
# Epoch 2/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3896 - accuracy: 0.8962 - val_loss: 0.3340 - val_accuracy: 0.9097
# Epoch 3/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3385 - accuracy: 0.9082 - val_loss: 0.3070 - val_accuracy: 0.9157
# Epoch 4/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3147 - accuracy: 0.9126 - val_loss: 0.2943 - val_accuracy: 0.9183
# Epoch 5/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3003 - accuracy: 0.9164 - val_loss: 0.2856 - val_accuracy: 0.9210
# Epoch 6/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2905 - accuracy: 0.9190 - val_loss: 0.2780 - val_accuracy: 0.9236
# Epoch 7/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2832 - accuracy: 0.9211 - val_loss: 0.2753 - val_accuracy: 0.9238
# Epoch 8/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2779 - accuracy: 0.9221 - val_loss: 0.2706 - val_accuracy: 0.9251
# Epoch 9/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2734 - accuracy: 0.9237 - val_loss: 0.2667 - val_accuracy: 0.9267
# Epoch 10/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2697 - accuracy: 0.9244 - val_loss: 0.2675 - val_accuracy: 0.9276
# Epoch 11/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2664 - accuracy: 0.9259 - val_loss: 0.2646 - val_accuracy: 0.9273
# Epoch 12/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2638 - accuracy: 0.9257 - val_loss: 0.2655 - val_accuracy: 0.9269
# Epoch 13/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2618 - accuracy: 0.9265 - val_loss: 0.2627 - val_accuracy: 0.9279
# Epoch 14/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2595 - accuracy: 0.9269 - val_loss: 0.2631 - val_accuracy: 0.9283
# Epoch 15/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.9280 - val_loss: 0.2630 - val_accuracy: 0.9283
# Epoch 16/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2558 - accuracy: 0.9288 - val_loss: 0.2620 - val_accuracy: 0.9298
# Epoch 17/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2544 - accuracy: 0.9294 - val_loss: 0.2596 - val_accuracy: 0.9300
# Epoch 18/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2527 - accuracy: 0.9296 - val_loss: 0.2602 - val_accuracy: 0.9301
# Epoch 19/30
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2515 - accuracy: 0.9305 - val_loss: 0.2598 - val_accuracy: 0.9294
# Epoch 20/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9306 - val_loss: 0.2614 - val_accuracy: 0.9290
# Epoch 21/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2492 - accuracy: 0.9308 - val_loss: 0.2594 - val_accuracy: 0.9307
# Epoch 22/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.9310 - val_loss: 0.2585 - val_accuracy: 0.9301
# Epoch 23/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.9313 - val_loss: 0.2593 - val_accuracy: 0.9295
# Epoch 24/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.9319 - val_loss: 0.2577 - val_accuracy: 0.9313
# Epoch 25/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2452 - accuracy: 0.9320 - val_loss: 0.2587 - val_accuracy: 0.9302
# Epoch 26/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2443 - accuracy: 0.9321 - val_loss: 0.2600 - val_accuracy: 0.9298
# Epoch 27/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 0.9323 - val_loss: 0.2603 - val_accuracy: 0.9304
# Epoch 28/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.9329 - val_loss: 0.2628 - val_accuracy: 0.9295
# Epoch 29/30
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9325 - val_loss: 0.2593 - val_accuracy: 0.9308
# Epoch 30/30
# 375/375 [==============================] - 1s 1ms/step - loss: 0.2414 - accuracy: 0.9336 - val_loss: 0.2594 - val_accuracy: 0.9309

# %% [markdown]
# Ocena modelu

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_probab = model.predict(X_test)
y_pred = np.argmax(y_probab, axis=1)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 313/313 [==============================] - 0s 820us/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       980
#            1       0.97      0.98      0.97      1135
#            2       0.93      0.90      0.91      1032
#            3       0.91      0.91      0.91      1010
#            4       0.93      0.94      0.93       982
#            5       0.89      0.89      0.89       892
#            6       0.94      0.95      0.94       958
#            7       0.93      0.93      0.93      1028
#            8       0.88      0.89      0.89       974
#            9       0.93      0.90      0.91      1009
#
#     accuracy                           0.93     10000
#    macro avg       0.93      0.93      0.93     10000
# weighted avg       0.93      0.93      0.93     10000
#
# [[ 958    0    1    2    0    7    9    2    1    0]
#  [   0 1110    4    3    0    1    3    2   12    0]
#  [   3    9  927   17    8    5   14    9   37    3]
#  [   3    0   17  920    1   28    2   10   24    5]
#  [   1    1    6    1  923    0    9    4    9   28]
#  [   7    2    3   29    8  796   14    6   24    3]
#  [   9    3    9    1    7   15  911    1    2    0]
#  [   1    6   22    7    8    1    0  953    2   28]
#  [   7    5    7   19    9   30    9   11  871    6]
#  [  11    7    1   11   30    9    0   25    8  907]]

# %% [markdown]
# Uczenie modeli nieliniowych

# %% [markdown]
# MLP

# %%
model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            keras.layers.Flatten(),
            layers.Dense(64, activation="tanh"),
            layers.Dense(128, activation="tanh"),
            layers.Dense(num_classes, activation="softmax")
        ]
    )

# %%
model.summary()
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(X_train, y_train, batch_size=batch_size, epochs=6, validation_split=0.2)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_12 (Dense)            (None, 64)                50240
#
#  dense_13 (Dense)            (None, 128)               8320
#
#  dense_14 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 59,850
# Trainable params: 59,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/6
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4100 - accuracy: 0.8837 - val_loss: 0.2337 - val_accuracy: 0.9337
# Epoch 2/6
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2013 - accuracy: 0.9407 - val_loss: 0.1715 - val_accuracy: 0.9513
# Epoch 3/6
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1444 - accuracy: 0.9568 - val_loss: 0.1390 - val_accuracy: 0.9610
# Epoch 4/6
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1135 - accuracy: 0.9663 - val_loss: 0.1273 - val_accuracy: 0.9637
# Epoch 5/6
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0909 - accuracy: 0.9724 - val_loss: 0.1088 - val_accuracy: 0.9682
# Epoch 6/6
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0739 - accuracy: 0.9777 - val_loss: 0.1030 - val_accuracy: 0.9693

# %%
y_probab = model.predict(X_test)
y_pred = np.argmax(y_probab, axis=1)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 313/313 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.95      0.96      1032
#            3       0.96      0.97      0.96      1010
#            4       0.97      0.97      0.97       982
#            5       0.95      0.97      0.96       892
#            6       0.97      0.97      0.97       958
#            7       0.96      0.96      0.96      1028
#            8       0.96      0.96      0.96       974
#            9       0.96      0.95      0.95      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#
# [[ 960    0    0    2    0    5    7    1    2    3]
#  [   0 1124    3    0    0    1    3    1    3    0]
#  [   7    2  979    9    4    2    5   10   13    1]
#  [   0    0    1  975    0   12    1    8   10    3]
#  [   0    0    4    1  949    1    6    2    1   18]
#  [   2    0    0    8    2  865    6    1    3    5]
#  [   6    3    1    0    3    8  932    0    5    0]
#  [   1    7   10    8    1    0    0  988    1   12]
#  [   3    1    3    7    5    6    3    5  938    3]
#  [   2    4    0    8   15    6    0    9    2  963]]

# %% [markdown]
# Sieć Konwolucyjna

# %%
model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Flatten(),
            layers.Dropout(0.5),
            layers.Dense(num_classes, activation="softmax"),
        ]
    )

# %%
model.summary()
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_5 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_11 (Dense)            (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=batch_size, epochs=3, validation_split=0.2)
# Out:
# Epoch 1/3
# 375/375 [==============================] - 13s 34ms/step - loss: 0.4005 - accuracy: 0.8785 - val_loss: 0.1065 - val_accuracy: 0.9691
# Epoch 2/3
# 375/375 [==============================] - 13s 35ms/step - loss: 0.1221 - accuracy: 0.9632 - val_loss: 0.0698 - val_accuracy: 0.9797
# Epoch 3/3
# 375/375 [==============================] - 14s 38ms/step - loss: 0.0900 - accuracy: 0.9724 - val_loss: 0.0579 - val_accuracy: 0.9840

# %%
y_probab = model.predict(X_test)
y_pred = np.argmax(y_probab, axis=1)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      1.00      0.99      1135
#            2       0.97      0.99      0.98      1032
#            3       0.98      0.99      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.99      0.98      0.98       892
#            6       0.99      0.99      0.99       958
#            7       0.98      0.97      0.98      1028
#            8       0.98      0.98      0.98       974
#            9       0.99      0.97      0.98      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.99      0.98      0.98     10000
# weighted avg       0.99      0.98      0.98     10000
#
# [[ 972    0    2    0    0    1    1    1    3    0]
#  [   0 1131    3    0    0    0    0    0    1    0]
#  [   1    4 1022    1    1    0    0    2    1    0]
#  [   0    0    3  996    0    5    0    4    2    0]
#  [   1    0    1    0  972    0    1    1    3    3]
#  [   1    0    2    6    0  877    2    1    1    2]
#  [   4    3    1    0    1    2  946    0    1    0]
#  [   0    3   15    4    0    1    0 1001    2    2]
#  [   6    0    4    2    1    0    1    5  951    4]
#  [   3    4    0    3    4    4    0    6    3  982]]
